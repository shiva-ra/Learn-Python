# %%
a = [[2,1,3],[5,4,0]]

print(a[0])
print(a[1])


def get_coord(num):
    for i in range(2):
        for j in range(3):

            if a[i][j] == num:
                return [i, j]

def possible_moves():
    
    if coord_zero == [0,0]:
        return [[0,1],[1,0]]
        
    elif coord_zero == [0,2]:
        
        return [[0,1],[1,2]]
        
    elif coord_zero == [1,0]:
        
        return [[0,0],[1,1]]
        
    elif coord_zero == [1,2]:
        
        return [[0,2],[1,1]]
        
    elif coord_zero == [0,1]:
        return [[0,0],[0,2],[1,1]]
        
    elif coord_zero == [1,1]:
        return [[0,1],[1,2],[1,0]]

def swap(coord_zero, coord_num):
    
    i,j,m,n = coord_zero[0], coord_zero[1], coord_num[0], coord_num[1]

    a[i][j], a[m][n] = a[m][n], a[i][j]
    
stop = False

while not stop:
    
    coord_zero = get_coord(0)
    
    while True and not stop:

        user = input('Enter the number to swap: ')

        if not user.isdigit():
            stop = True
        else:
            num = int(user)    

            coord_num = get_coord(num)

            if coord_num in possible_moves():
                break

    swap(coord_zero, coord_num)

    print(a[0])
    print(a[1])

# %%
a = [[3,2,4],[1,5,0]]

print(a[0])
print(a[1])


def get_coord(num):
    for i in range(2):
        for j in range(3):

            if a[i][j] == num:
                return [i, j]

def possible_moves():
    
    if coord_zero == [0,0]:
        return [[0,1],[1,0]]
        
    elif coord_zero == [0,2]:
        
        return [[0,1],[1,2]]
        
    elif coord_zero == [1,0]:
        
        return [[0,0],[1,1]]
        
    elif coord_zero == [1,2]:
        
        return [[0,2],[1,1]]
        
    elif coord_zero == [0,1]:
        return [[0,0],[0,2],[1,1]]
        
    elif coord_zero == [1,1]:
        return [[0,1],[1,2],[1,0]]

def swap(coord_zero, coord_num):
    
    i,j,m,n = coord_zero[0], coord_zero[1], coord_num[0], coord_num[1]

    a[i][j], a[m][n] = a[m][n], a[i][j]
    
stop = False

while not stop:
    
    coord_zero = get_coord(0)
    
    while True and not stop:

        user = input('Enter the number to swap: ')

        if not user.isdigit():
            stop = True
        else:
            num = int(user)    

            coord_num = get_coord(num)

            if coord_num in possible_moves():
                break

    swap(coord_zero, coord_num)

    print(a[0])
    print(a[1])
